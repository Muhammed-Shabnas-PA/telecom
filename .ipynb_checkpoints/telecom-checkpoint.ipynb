# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
import warnings
warnings.filterwarnings('ignore')
pd.options.display.float_format = '{:.2f}'.format

# %%
data = pd.read_csv('Telecom_Customer_Details.csv')
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.shape
# Out:
# (7043, 21)

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
sns.heatmap(data.isnull(), cbar=False, cmap='coolwarm')
# Out:
# <Axes: >

# %%
print('Columns\t\tMissing Values')
print('********************************')
print(data.isnull().sum())
# Out:
# Columns		Missing Values
# ********************************
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
print('Columns\t\t    Data Type')
print('******************************')
print(data.dtypes)
# Out:
# Columns		    Data Type
# ******************************
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
data.describe().T
# Out:
#                  count  mean   std   min   25%   50%   75%    max
# SeniorCitizen  7043.00  0.16  0.37  0.00  0.00  0.00  0.00   1.00
# tenure         7043.00 32.37 24.56  0.00  9.00 29.00 55.00  72.00
# MonthlyCharges 7043.00 64.76 30.09 18.25 35.50 70.35 89.85 118.75

# %%
data.TotalCharges.value_counts()
# Out:
# TotalCharges
#           11
# 20.2      11
# 19.75      9
# 20.05      8
# 19.9       8
#           ..
# 6849.4     1
# 692.35     1
# 130.15     1
# 3211.9     1
# 6844.5     1
# Name: count, Length: 6531, dtype: int64

# %%
data['TotalCharges'] = data['TotalCharges'].replace(" ", np.nan)

# %%
data['TotalCharges'].isnull().sum()/len(data)*100
# Out:
# 0.1561834445548772

# %%
data = data[data['TotalCharges'].notnull()]
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.shape
# Out:
# (7032, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %%
data['TotalCharges'] = data['TotalCharges'].astype('float')

# %%
#customerID has not significant for predicting data, so we can drop it

data.drop('customerID', axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7032 non-null   object
#  1   SeniorCitizen     7032 non-null   int64
#  2   Partner           7032 non-null   object
#  3   Dependents        7032 non-null   object
#  4   tenure            7032 non-null   int64
#  5   PhoneService      7032 non-null   object
#  6   MultipleLines     7032 non-null   object
#  7   InternetService   7032 non-null   object
#  8   OnlineSecurity    7032 non-null   object
#  9   OnlineBackup      7032 non-null   object
#  10  DeviceProtection  7032 non-null   object
#  11  TechSupport       7032 non-null   object
#  12  StreamingTV       7032 non-null   object
#  13  StreamingMovies   7032 non-null   object
#  14  Contract          7032 non-null   object
#  15  PaperlessBilling  7032 non-null   object
# ...

# %%
df1 = data.copy(deep=True)

# %%
#Label Encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

text_data_features = [i for i in list(df1.columns) if i not in list(df1.describe().columns)]

print('Label Encoder Transformation')
for i in text_data_features:
    df1[i] = le.fit_transform(df1[i])
    print(i, ' : ', df1[i].unique(), ' = ', le.inverse_transform(df1[i].unique()))
# Out:
# Label Encoder Transformation
# gender  :  [0 1]  =  ['Female' 'Male']
# Partner  :  [1 0]  =  ['Yes' 'No']
# Dependents  :  [0 1]  =  ['No' 'Yes']
# PhoneService  :  [0 1]  =  ['No' 'Yes']
# MultipleLines  :  [1 0 2]  =  ['No phone service' 'No' 'Yes']
# InternetService  :  [0 1 2]  =  ['DSL' 'Fiber optic' 'No']
# OnlineSecurity  :  [0 2 1]  =  ['No' 'Yes' 'No internet service']
# OnlineBackup  :  [2 0 1]  =  ['Yes' 'No' 'No internet service']
# DeviceProtection  :  [0 2 1]  =  ['No' 'Yes' 'No internet service']
# TechSupport  :  [0 2 1]  =  ['No' 'Yes' 'No internet service']
# StreamingTV  :  [0 2 1]  =  ['No' 'Yes' 'No internet service']
# StreamingMovies  :  [0 2 1]  =  ['No' 'Yes' 'No internet service']
# Contract  :  [0 1 2]  =  ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling  :  [1 0]  =  ['Yes' 'No']
# PaymentMethod  :  [2 3 0 1]  =  ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn  :  [0 1]  =  ['No' 'Yes']

# %%
df1.describe().T
# Out:
#                    count    mean     std   min    25%     50%     75%     max
# gender           7032.00    0.50    0.50  0.00   0.00    1.00    1.00    1.00
# SeniorCitizen    7032.00    0.16    0.37  0.00   0.00    0.00    0.00    1.00
# Partner          7032.00    0.48    0.50  0.00   0.00    0.00    1.00    1.00
# Dependents       7032.00    0.30    0.46  0.00   0.00    0.00    1.00    1.00
# tenure           7032.00   32.42   24.55  1.00   9.00   29.00   55.00   72.00
# PhoneService     7032.00    0.90    0.30  0.00   1.00    1.00    1.00    1.00
# MultipleLines    7032.00    0.94    0.95  0.00   0.00    1.00    2.00    2.00
# InternetService  7032.00    0.87    0.74  0.00   0.00    1.00    1.00    2.00
# OnlineSecurity   7032.00    0.79    0.86  0.00   0.00    1.00    2.00    2.00
# OnlineBackup     7032.00    0.91    0.88  0.00   0.00    1.00    2.00    2.00
# DeviceProtection 7032.00    0.90    0.88  0.00   0.00    1.00    2.00    2.00
# ...

# %%
df1.Churn.value_counts()
# Out:
# Churn
# 0    5163
# 1    1869
# Name: count, dtype: int64

# %%
churn = df1[df1['Churn']==1].describe().T
not_churn = df1[df1['Churn']==0].describe().T

plt.figure(figsize=(6,6))
plt.subplot(1,2,1)
sns.heatmap(churn[['mean']], annot=True, fmt='0.2f', cmap='coolwarm', linewidths=0.4, linecolor='black', cbar=False)
plt.title('Churned Customer')

plt.subplot(1,2,2)
sns.heatmap(not_churn[['mean']], annot=True, fmt='0.2f', cmap='coolwarm', linewidths=0.4, linecolor='black', cbar=False)
plt.title('Not Churned Customer')

plt.tight_layout()
plt.show()

# %% [markdown]
# # EDA

# %%
df1.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
df1.describe().T
# Out:
#                    count    mean     std   min    25%     50%     75%     max
# gender           7032.00    0.50    0.50  0.00   0.00    1.00    1.00    1.00
# SeniorCitizen    7032.00    0.16    0.37  0.00   0.00    0.00    0.00    1.00
# Partner          7032.00    0.48    0.50  0.00   0.00    0.00    1.00    1.00
# Dependents       7032.00    0.30    0.46  0.00   0.00    0.00    1.00    1.00
# tenure           7032.00   32.42   24.55  1.00   9.00   29.00   55.00   72.00
# PhoneService     7032.00    0.90    0.30  0.00   1.00    1.00    1.00    1.00
# MultipleLines    7032.00    0.94    0.95  0.00   0.00    1.00    2.00    2.00
# InternetService  7032.00    0.87    0.74  0.00   0.00    1.00    1.00    2.00
# OnlineSecurity   7032.00    0.79    0.86  0.00   0.00    1.00    2.00    2.00
# OnlineBackup     7032.00    0.91    0.88  0.00   0.00    1.00    2.00    2.00
# DeviceProtection 7032.00    0.90    0.88  0.00   0.00    1.00    2.00    2.00
# ...

# %%
col = list(df1.columns)
categorical_features = []
numerical_features = []

for i in col:
    if df1[i].nunique() >6:
        numerical_features.append(i)
    else:
        categorical_features.append(i)

print('categorical features: ', categorical_features)
print('numerical features: ', numerical_features)
# Out:
# categorical features:  ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'Churn']
# numerical features:  ['tenure', 'MonthlyCharges', 'TotalCharges']

# %%
l = list(df1['Churn'].value_counts())
churn_perc = [ l[0]/sum(l)*100 , l[1]/sum(l)*100 ]

fig = plt.subplots(nrows = 1, ncols = 2, figsize = (20, 6))
plt.subplot(1,2,1)
plt.pie(churn_perc, labels= ['Not-Churn Customer', 'Churn Customer'], autopct='%1.1f%%', startangle=90, explode=(0.1,0),
        colors=['brown', 'royalblue'], wedgeprops={'edgecolor' : 'black', 'linewidth': 1, 'antialiased':True})
plt.title('Churn - Not Churn %')

plt.subplot(1,2,2)
ax = sns.countplot(x='Churn', data=df1, palette=['brown', 'royalblue'], edgecolor = 'black')
for rect in ax.patches:
    ax.text(rect.get_x()+rect.get_width()/2,rect.get_height()+50,rect.get_height(), horizontalalignment='center', fontsize=12)
ax.set_xticklabels(['Not-Churn Customer', 'Churn Customer'])
plt.title('Number of Churn - Not Churn Customer')


plt.show()

# %%
categorical_features
# Out:
# ['gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Churn']

# %%
# Removing Churn variable as it's target
categorical_features.remove('Churn')

# %%
categorical_features
# Out:
# ['gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod']

# %%
numerical_features
# Out:
# ['tenure', 'MonthlyCharges', 'TotalCharges']

# %%
# Case 1 : Customer information
# Case 2 : Payment information 
# Case 3 : Service Subscribed

# %%
Customer_information = ['gender','SeniorCitizen','Partner','Dependents']
Payment_information = ['PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity','OnlineBackup',  
                       'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']
Service_Subscribed = ['Contract',  'PaperlessBilling',  'PaymentMethod']

# %% [markdown]
# ### Case 1 : Customer information

# %%
Customer_information
# Out:
# ['gender', 'SeniorCitizen', 'Partner', 'Dependents']

# %%
fig = plt.subplots(ncols=2, nrows=2, figsize=(15,10))

for i in range(len(Customer_information)):
    plt.subplot(2,2,i+1)
    ax = sns.countplot(x = Customer_information[i], data=data, hue='Churn', palette=['brown', 'royalblue'], edgecolor='black')
    for rect in ax.patches:
        ax.text(rect.get_x()+ rect.get_width()/2, rect.get_height()+40, rect.get_height(), horizontalalignment = 'center')
    plt.title(Customer_information[i]+ ' vs Churn')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Case 2 : Payment information

# %%
Payment_information
# Out:
# ['PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies']

# %%
fig = plt.subplots(ncols=3, nrows=3, figsize=(15,10))

for i in range(len(Payment_information)):
    plt.subplot(3,3,i+1)
    ax = sns.countplot(x = Payment_information[i], data=df1, hue='Churn', palette=['brown', 'royalblue'], edgecolor='black')
    for rect in ax.patches:
        ax.text(rect.get_x()+ rect.get_width()/2, rect.get_height()+40, rect.get_height(), horizontalalignment = 'center')
    plt.title(Payment_information[i]+ ' vs Churn')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Case 3 : Service Subscribed

# %%
Service_Subscribed
# Out:
# ['Contract', 'PaperlessBilling', 'PaymentMethod']

# %%
fig = plt.subplots(ncols=3, nrows=1, figsize=(20,6))

for i in range(len(Service_Subscribed)):
    plt.subplot(1,3,i+1)
    ax = sns.countplot(x = Service_Subscribed[i], data=df1, hue='Churn', palette=['brown', 'royalblue'], edgecolor='black')
    for rect in ax.patches:
        ax.text(rect.get_x()+ rect.get_width()/2, rect.get_height()+25, rect.get_height(), horizontalalignment = 'center')
    plt.title(Service_Subscribed[i]+ ' vs Churn')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### numerical features

# %%
numerical_features
# Out:
# ['tenure', 'MonthlyCharges', 'TotalCharges']

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize = (18,5))
for i in range(len(numerical_features)):
    plt.subplot(1,3,i+1)
    sns.distplot(df1[numerical_features[i]], color='brown')
    plt.title('Distribution Plot :' + numerical_features[i])

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize = (20,10))
for i in range(len(numerical_features)):
    plt.subplot(1,3,i+1)
    sns.histplot(x = numerical_features[i], data=df1, color='brown', hue='Churn', kde=True, element='step')
    plt.title('Distribution Plot :' + numerical_features[i])

plt.tight_layout()
plt.show()

# %%
fig = plt.subplots(ncols=1, nrows=3, figsize=(15,10))

for i in range(len(numerical_features)):
    plt.subplot(3,1,i+1)
    ax = sns.countplot(x = numerical_features[i], data=df1, hue='Churn', palette=['brown', 'royalblue'], edgecolor='black')
    # for rect in ax.patches:
    #     ax.text(rect.get_x()+ rect.get_width()/2, rect.get_height()+40, rect.get_height(), horizontalalignment = 'center')
    plt.title(numerical_features[i]+ ' vs Churn')

plt.tight_layout()
plt.show()

# %%
import plotly.graph_objs as go
import plotly.express as px
import plotly.offline as po

# %% [markdown]
# ### Churn rate by Tenure

# %%
tenure_churn = df1.groupby('tenure').Churn.mean().reset_index()
tenure_churn
# Out:
#     tenure  Churn
# 0        1   0.62
# 1        2   0.52
# 2        3   0.47
# 3        4   0.47
# 4        5   0.48
# ..     ...    ...
# 67      68   0.09
# 68      69   0.08
# 69      70   0.09
# 70      71   0.04
# 71      72   0.02
#
# [72 rows x 2 columns]

# %%
fig = go.Figure(data=[go.Scatter(x=tenure_churn['tenure'], y=tenure_churn['Churn'], mode='markers',
                                 name='low', marker={'size' :5, 'color':'blue', 'line':{'width':0.8}})])
fig.update_layout(title = 'Churn rate by Tenure' ,xaxis_title = 'Tenure', yaxis_title = 'Churn',template = 'plotly_dark')

fig.show()

# %% [markdown]
# ### Feature Scaling

# %%
df1.describe()
# Out:
#        gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# count 7032.00        7032.00  7032.00     7032.00 7032.00       7032.00
# mean     0.50           0.16     0.48        0.30   32.42          0.90
# std      0.50           0.37     0.50        0.46   24.55          0.30
# min      0.00           0.00     0.00        0.00    1.00          0.00
# 25%      0.00           0.00     0.00        0.00    9.00          1.00
# 50%      1.00           0.00     0.00        0.00   29.00          1.00
# 75%      1.00           0.00     1.00        1.00   55.00          1.00
# max      1.00           1.00     1.00        1.00   72.00          1.00
#
#        MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# count        7032.00          7032.00         7032.00       7032.00
# mean            0.94             0.87            0.79          0.91
# std             0.95             0.74            0.86          0.88
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

for i in range(len(numerical_features)):
    df1[numerical_features[i]] = scaler.fit_transform(df1[[numerical_features[i]]])

df1.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0   -1.28             0
# 1       1              0        0           0    0.06             1
# 2       1              0        0           0   -1.24             1
# 3       1              0        0           0    0.51             0
# 4       0              0        0           0   -1.24             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
df1.describe()
# Out:
#        gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# count 7032.00        7032.00  7032.00     7032.00 7032.00       7032.00
# mean     0.50           0.16     0.48        0.30   -0.00          0.90
# std      0.50           0.37     0.50        0.46    1.00          0.30
# min      0.00           0.00     0.00        0.00   -1.28          0.00
# 25%      0.00           0.00     0.00        0.00   -0.95          1.00
# 50%      1.00           0.00     0.00        0.00   -0.14          1.00
# 75%      1.00           0.00     1.00        1.00    0.92          1.00
# max      1.00           1.00     1.00        1.00    1.61          1.00
#
#        MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# count        7032.00          7032.00         7032.00       7032.00
# mean            0.94             0.87            0.79          0.91
# std             0.95             0.74            0.86          0.88
# ...

# %% [markdown]
# ### Correlation

# %%
plt.figure(figsize=(20,8))
sns.heatmap(df1.corr(), annot=True, fmt = '0.2g', cmap='Reds')
# Out:
# <Axes: >

# %%
corr = df1.corrwith(df1['Churn']).sort_values(ascending=False).to_frame()
corr.columns = ['Correlation']

plt.figure(figsize=(5,5))
sns.heatmap(corr, annot=True, fmt = '0.2g', cmap='Reds', linewidths=0.4, linecolor='black')
plt.title("Correlation Matrix w.r.t. outcomes")
plt.show()

# %% [markdown]
# ## Selection of Features

# %% [markdown]
# ### Selection of Categorical Features

# %%
# for categorical_features - chi-square test
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2, mutual_info_classif

# %%
# Chi-Square Test :
features = df1.loc[:, categorical_features]
target = df1.loc[:, 'Churn']
best_features = SelectKBest(score_func=chi2, k='all')
fit = best_features.fit(features, target)

feature_score = pd.DataFrame(fit.scores_, index=list(features.columns), columns=['Chi Squared Score'])

plt.figure(figsize=(5,5))
sns.heatmap(feature_score.sort_values(ascending=False, by=['Chi Squared Score']), annot=True, fmt = '0.2f', cmap='Reds', linewidths=0.4, linecolor='black')
plt.title("Selection of Categorical Features")
plt.show()

# %% [markdown]
# ### Selection of Numerical Features

# %%
# for numerical_features  - Anova test
from sklearn.feature_selection import f_classif

# %%
# Chi-Square Test :
features = df1.loc[:, numerical_features]
target = df1.loc[:, 'Churn']
best_features = SelectKBest(score_func=f_classif, k='all')
fit = best_features.fit(features, target)

feature_score = pd.DataFrame(fit.scores_, index=list(features.columns), columns=['ANOVA Score'])

plt.figure(figsize=(5,5))
sns.heatmap(feature_score.sort_values(ascending=False, by=['ANOVA Score']), annot=True, fmt = '0.2f', cmap='Reds', linewidths=0.4, linecolor='black')
plt.title("Selection of Numerical Features")
plt.show()

# %%
# Drop the non-significant variable
df1.drop(columns = ['gender','PhoneService','StreamingTV','StreamingMovies','InternetService','MultipleLines'], inplace=True)
df1.head()
# Out:
#    SeniorCitizen  Partner  Dependents  tenure  OnlineSecurity  OnlineBackup  \
# 0              0        1           0   -1.28               0             2
# 1              0        0           0    0.06               2             0
# 2              0        0           0   -1.24               2             2
# 3              0        0           0    0.51               2             0
# 4              0        0           0   -1.24               0             0
#
#    DeviceProtection  TechSupport  Contract  PaperlessBilling  PaymentMethod  \
# 0                 0            0         0                 1              2
# 1                 2            0         1                 0              3
# 2                 0            0         0                 1              3
# 3                 2            2         1                 0              0
# 4                 0            0         0                 1              2
#
#    MonthlyCharges  TotalCharges  Churn
# ...

# %% [markdown]
# ## Handling imbalance dataset

# %%
df1['Churn'].value_counts()
# Out:
# Churn
# 0    5163
# 1    1869
# Name: count, dtype: int64

# %%
df1['Churn'].value_counts(normalize=True)
# Out:
# Churn
# 0   0.73
# 1   0.27
# Name: proportion, dtype: float64

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE()

f1 = df1.iloc[:,:-1].values
t1 = df1.iloc[:,-1].values

f1, t1 = smote.fit_resample(f1,t1)

print(df1.iloc[:,-1].value_counts())
print(pd.DataFrame(t1).value_counts())
# Out:
# Churn
# 0    5163
# 1    1869
# Name: count, dtype: int64
# 0
# 0    5163
# 1    5163
# Name: count, dtype: int64

# %% [markdown]
# ## Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.metrics import roc_curve, precision_recall_curve, roc_auc_score
from sklearn.model_selection import cross_val_score, GridSearchCV, RepeatedStratifiedKFold

# %%
x_train, x_test, y_train, y_test = train_test_split(f1, t1, test_size=0.2, random_state=42)

# %%
def model(classifier, x_train, y_train, x_test, y_test):
    classifier.fit(x_train, y_train)
    prediction = classifier.predict(x_test)
    cv = RepeatedStratifiedKFold(n_repeats=3, n_splits=10, random_state=10)
    cv_score = cross_val_score(classifier, x_train, y_train, cv=cv, scoring='roc_auc').mean()
    print('Cross Validation Score: ', '{0:.2%}'.format(cv_score))
    r_a_score = roc_auc_score(y_test, prediction)
    print('ROC AUC Score', '{0:.2%}'.format(r_a_score))
    try:
        y_predict_proba = classifier.predict_proba(x_test)[:,1]
        fpr, tpr, threshold = roc_curve(y_test, y_predict_proba)
        plt.plot(fpr, tpr)
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('ROC Curve')
        plt.show()
    except AttributeError:
        print("Classifier does not have predict_proba method. Cannot plot ROC curve.")

# %%
def model_evaluation(classifier, x_test, y_test):
    prediction = classifier.predict(x_test)
    cm = confusion_matrix(y_test, prediction)
    names = ['True Neg', 'False Pos', 'False Neg', 'True Pos']
    count = [value for value in cm.flatten()]
    percentage = ['{:.2%}'.format(value) for value in cm.flatten()/np.sum(cm)]
    labels = [f'{v1}\n{v2}\n{v3}' for v1, v2, v3 in zip(names, count, percentage)]
    labels = np.asarray(labels).reshape(2,2)
    sns.heatmap(cm, annot=labels, cmap='Blues', fmt = '')
    print('Accuracy Score: ', accuracy_score(y_test, prediction))
    print('Classfication Report:\n', classification_report(y_test, prediction))

# %% [markdown]
# ### RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# Define the parameter grid for RandomForestClassifier
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Create a RandomForestClassifier
rf_classifier = RandomForestClassifier(random_state=42)

# Create a GridSearchCV object
grid_search = GridSearchCV(estimator=rf_classifier, param_grid=param_grid, cv=5, scoring='roc_auc', n_jobs=-1)


# Fit the grid search to the training data
grid_search.fit(x_train, y_train)

# Get the best hyperparameters and the best score
best_params = grid_search.best_params_

print(f"Best Hyperparameters: {best_params}")
# Out:
# Best Hyperparameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}

# %%
rf_classifier = RandomForestClassifier(max_depth= None, min_samples_leaf= 1, min_samples_split= 2, n_estimators= 200,random_state=42)

# %%
model(rf_classifier, x_train, y_train, x_test, y_test)
# Out:
# Cross Validation Score:  91.91%
# ROC AUC Score 84.32%

# %%
model_evaluation(rf_classifier, x_test, y_test)
# Out:
# Accuracy Score:  0.8431752178121975
# Classfication Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.84      0.84      1037
#            1       0.84      0.85      0.84      1029
#
#     accuracy                           0.84      2066
#    macro avg       0.84      0.84      0.84      2066
# weighted avg       0.84      0.84      0.84      2066

# %% [markdown]
# ### XGBClassifier

# %%
from xgboost import XGBClassifier

# Define the parameter grid for XGBoost
param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.2],
    'n_estimators': [100, 200, 300],
    'subsample': [0.8, 0.9, 1.0],
}

# Create an XGBoost classifier
xgb_classifier = XGBClassifier(random_state=42, eval_metric='logloss')

# Create a GridSearchCV object
grid_search = GridSearchCV(estimator=xgb_classifier, param_grid=param_grid, cv=5, scoring='roc_auc', n_jobs=-1)

# Fit the grid search to the training data
grid_search.fit(x_train, y_train)

# Get the best hyperparameters and the best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print(f"Best Hyperparameters: {best_params}")
print(f"Best ROC AUC Score: {best_score}")
# Out:
# Best Hyperparameters: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'subsample': 0.9}
# Best ROC AUC Score: 0.9245257618309577

# %%
xgb_classifier = XGBClassifier(learning_rate= 0.1, max_depth= 5, n_estimators= 200, subsample= 0.9, random_state=42, eval_metric='logloss')

# %%
model(xgb_classifier, x_train, y_train, x_test, y_test)
# Out:
# Cross Validation Score:  92.62%
# ROC AUC Score 83.89%

# %%
model_evaluation(xgb_classifier, x_test, y_test)
# Out:
# Accuracy Score:  0.8388189738625363
# Classfication Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84      1037
#            1       0.83      0.85      0.84      1029
#
#     accuracy                           0.84      2066
#    macro avg       0.84      0.84      0.84      2066
# weighted avg       0.84      0.84      0.84      2066

# %% [markdown]
# ### AdaBoostClassifier

# %%
from sklearn.ensemble import AdaBoostClassifier

# Define the parameter grid for AdaBoostClassifier
param_grid_ada = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 1.0]
}

# Create an AdaBoostClassifier
ada_classifier = AdaBoostClassifier(random_state=42)

# Create a GridSearchCV object for AdaBoost
grid_search_ada = GridSearchCV(estimator=ada_classifier, param_grid=param_grid_ada, cv=5, scoring='roc_auc', n_jobs=-1)

# Fit the grid search to the training data
grid_search_ada.fit(x_train, y_train)

# Get the best hyperparameters and the best score
best_params_ada = grid_search_ada.best_params_

print(f"Best Hyperparameters for AdaBoost: {best_params_ada}")
# Out:
# Best Hyperparameters for AdaBoost: {'learning_rate': 1.0, 'n_estimators': 200}

# %%
ada_classifier = AdaBoostClassifier(learning_rate= 1.0, n_estimators= 200,random_state=42)

# %%
model(ada_classifier, x_train, y_train, x_test, y_test)
# Out:
# Cross Validation Score:  91.00%
# ROC AUC Score 82.98%

# %%
model_evaluation(ada_classifier, x_test, y_test)
# Out:
# Accuracy Score:  0.829622458857696
# Classfication Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.80      0.82      1037
#            1       0.81      0.86      0.83      1029
#
#     accuracy                           0.83      2066
#    macro avg       0.83      0.83      0.83      2066
# weighted avg       0.83      0.83      0.83      2066

# %% [markdown]
# ### GradientBoostingClassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

# Define the parameter grid for GradientBoostingClassifier
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 1],
    'max_depth': [3, 5, 7],
    'min_samples_split': [2, 5, 10]
}

# Create a GradientBoostingClassifier
gb_classifier = GradientBoostingClassifier(random_state=42)

# Create a GridSearchCV object
grid_search = GridSearchCV(estimator=gb_classifier, param_grid=param_grid, cv=5, scoring='roc_auc', n_jobs=-1)

# Fit the grid search to the training data
grid_search.fit(x_train, y_train)

# Get the best hyperparameters and the best score
best_params = grid_search.best_params_

print(f"Best Hyperparameters: {best_params}")
# Out:
# Best Hyperparameters: {'learning_rate': 0.1, 'max_depth': 7, 'min_samples_split': 5, 'n_estimators': 200}

# %%
gb_classifier = GradientBoostingClassifier(learning_rate= 0.1, max_depth= 5, min_samples_split= 10, n_estimators= 200,random_state=42)

# %%
model(gb_classifier, x_train, y_train, x_test, y_test)
# Out:
# Cross Validation Score:  92.64%
# ROC AUC Score 84.08%

# %%
model_evaluation(gb_classifier, x_test, y_test)
# Out:
# Accuracy Score:  0.8407550822846079
# Classfication Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84      1037
#            1       0.83      0.86      0.84      1029
#
#     accuracy                           0.84      2066
#    macro avg       0.84      0.84      0.84      2066
# weighted avg       0.84      0.84      0.84      2066

# %% [markdown]
# ## Saving Model

# %%
import joblib
joblib.dump(xgb_classifier, 'xgb_model.pkl')
# Out:
# ['xgb_model.pkl']
